# %%
import pandas as pd
college = pd.read_csv('new_college.csv')
dictionary = pd.read_csv('CollegeScorecard_Raw_Data/CollegeScorecardDataDictionary-09-12-2015.csv')

# %%
dictionary.label[1]
# Out:
# nan

# %%
dmajor = {}
for i in range(len(dictionary)):
    if str(dictionary.label[i]) != 'nan':
        dmajor[dictionary['VARIABLE NAME'][i]] = dictionary.label[i]
print dmajor
# Out:
# {'PCIP04': 'Architecture and Related Services', 'PCIP05': 'Area, Ethnic, Cultural, Gender, and Group Studies', 'PCIP24': 'Liberal Arts and Sciences, General Studies and Humanities', 'PCIP25': 'Library Science', 'PCIP26': 'Biological and Biomedical Sciences', 'PCIP01': 'Agriculture, Agriculture Operations, and Related Sciences', 'PCIP42': 'Psychology', 'PCIP29': 'Military Technologies and Applied Sciences', 'PCIP40': 'Physical Sciences', 'PCIP41': 'Science Technologies/Technicians', 'PCIP46': 'Construction Trades', 'PCIP22': 'Legal Professions and Studies', 'PCIP44': 'Public Administration and Social Service Professions', 'PCIP09': 'Communication, Journalism, and Related Programs', 'PCIP23': 'English Language and Literature/Letters', 'PCIP47': 'Mechanic and Repair Technologies/Technicians', 'PCIP03': 'Natural Resources and Conservation', 'PCIP39': 'Theology and Religious Vocations', 'PCIP27': 'Mathematics and Statistics', 'PCIP43': 'Homeland Security, Law Enforcement, Firefighting and Related Protective Services', 'PCIP15': 'Engineering Technologies and Engineering-Related Fields', 'PCIP14': 'Engineering', 'PCIP16': 'Foreign Languages, Literatures, and Linguistics', 'PCIP11': 'Computer and Information Sciences and Support Services', 'PCIP10': 'Communications Technologies/Technicians and Support Services', 'PCIP13': 'Education', 'PCIP12': 'Personal and Culinary Services', 'PCIP51': 'Health Professions and Related Programs', 'PCIP50': 'Visual and Performing Arts', 'PCIP52': 'Business, Management, Marketing, and Related Support Services', 'PCIP19': 'Family and Consumer Sciences/Human Sciences', 'PCIP54': 'History', 'PCIP31': 'Parks, Recreation, Leisure, and Fitness Studies', 'PCIP30': 'Multi/Interdisciplinary Studies', 'PCIP38': 'Philosophy and Religious Studies', 'PCIP45': 'Social Sciences', 'PCIP48': 'Precision Production', 'PCIP49': 'Transportation and Materials Moving'}

# %%
dname = {}
for i in range(len(dictionary)):
    if str(dictionary['NAME OF DATA ELEMENT'][i]) != 'nan':
        dname[dictionary['VARIABLE NAME'][i]] = dictionary['NAME OF DATA ELEMENT'][i]
print dname
# Out:
# {'HI_INC_YR8_N': 'Number of high-income (above $75,000 in nominal family income) students in overall 8-year completion cohort', 'D150_4': 'Adjusted cohort count for completion rate at four-year institutions (denominator of completion rate)', 'FEMALE_WDRAW_ORIG_YR8_RT': 'Percent of female students withdrawn from original institution within 8 years', 'NOPELL_UNKN_2YR_TRANS_YR8_RT': 'Percent of students who never received a Pell Grant at the institution and who transferred to a 2-year institution and whose status is unknown within 8 years', 'DEBT_MDN_SUPP': 'Median debt, suppressed for n=30', 'MD_INC_YR6_N': 'Number of middle-income (between $30,000 and $75,000 in nominal family income) students in overall 6-year completion cohort', 'MALE_ENRL_ORIG_YR3_RT': 'Percent of male students who were still enrolled at original institution within 3 years', 'NOT1STGEN_WDRAW_2YR_TRANS_YR8_RT': 'Percent of not-first-generation students who transferred to a 2-year institution and withdrew within 8 years', 'LOAN_COMP_4YR_TRANS_YR8_RT': 'Percent of students who received a federal loan at the institution and who transferred to a 4-year institution and completed within 8 years', 'HI_INC_YR4_N': 'Number of high-income (above $75,000 in nominal family income) students in overall 4-year completion cohort', 'CIP42BACHL': "Bachelor's degree in Psychology.", 'C150_L4_NHPI': 'Completion rate for first-time, full-time students at less-than-four-year institutions (150% of expected time to completion/6 years) for Native Hawaiian/Pacific Islander students', 'MD_INC_YR8_N': 'Number of middle-income (between $30,000 and $75,000 in nominal family income) students in overall 8-year completion cohort', 'FIRSTGEN_YR8_N': 'Number of first-generation students in overall 8-year completion cohort', 'HI_INC_YR6_N': 'Number of high-income (above $75,000 in nominal family income) students in overall 6-year completion cohort', 'FIRSTGEN_COMP_2YR_TRANS_YR6_RT': 'Percent of first-generation students who transferred to a 2-year institution and completed within 6 years', 'NOPELL_UNKN_2YR_TRANS_YR2_RT': 'Percent of students who never received a Pell Grant at the institution and who transferred to a 2-year institution and whose status is unknown within 2 years', 'mn_earn_wne_p8': 'Mean earnings of students working and not enrolled 8 years after entry', 'NOTFIRSTGEN_RPY_3YR_N': 'Number of students in the 3-year repayment rate of not-first-generation students cohort', 'MALE_WDRAW_ORIG_YR4_RT': 'Percent of male students withdrawn from original institution within 4 years', 'pct_white': "Percent of the population from students' zip codes that is White, via Census data", 'mn_earn_wne_p7': 'Mean earnings of students working and not enrolled 7 years after entry', 'count_wne_p7': 'Number of students working and not enrolled 7 years after entry', 'count_wne_p6': 'Number of students working and not enrolled 6 years after entry', 'COMPL_RPY_3YR_N': 'Number of students in the 3-year repayment rate of completers cohort', 'NOLOAN_ENRL_ORIG_YR2_RT': 'Percent of students who never received a federal loan at the institution and who were still enrolled at original institution within 2 years ', 'IND_WDRAW_4YR_TRANS_YR2_RT': 'Percent of independent students who transferred to a 4-year institution and withdrew within 2 years ', 'DEP_UNKN_4YR_TRANS_YR6_RT': 'Percent of dependent students who transferred to a 4-year institution and whose status is unknown within 6 years', 'count_wne_p9': 'Number of students working and not enrolled 9 years after entry', 'NOLOAN_COMP_2YR_TRANS_YR6_RT': 'Percent of students who never received a federal loan at the institution and who transferred to a 2-year institution and completed within 6 years', 'MALE_ENRL_2YR_TRANS_YR3_RT': 'Percent of male students who transferred to a 2-year institution and were still enrolled within 3 years', 'FEMALE_COMP_ORIG_YR2_RT': 'Percent of female students who completed within 2 years at original institution', 'PAR_ED_N': "Number of stude ...
